# %%
# Installing Pandas
pip install pandas

# %%
# Installing Matplot Lib
pip install matplotlib

# %%
# Installing Seaborn
pip install seaborn

# %%
# Installing Scipy
pip install scipy

# %%
# Importing essential Libbraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats  import zscore

# %%
# Imprting the filing & loading it to a pandas Data Frame
path = r"C:\Users\henokt\OneDrive - Inchcape\Documents\KIAM8\Data\data\data\togo-dapaong_qc.csv"
df=pd.read_csv(path.replace('\\','/'))

# %%
# Exploring the Data Set
df.describe()
# Out:
#                  GHI            DNI            DHI           ModA  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      230.555040     151.258469     116.444352     226.144375
# std       322.532347     250.956962     156.520714     317.346938
# min       -12.700000       0.000000       0.000000       0.000000
# 25%        -2.200000       0.000000       0.000000       0.000000
# 50%         2.100000       0.000000       2.500000       4.400000
# 75%       442.400000     246.400000     215.700000     422.525000
# max      1424.000000    1004.500000     805.700000    1380.000000
#
#                 ModB           Tamb             RH             WS  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      219.568588      27.751788      55.013160       2.368093
# std       307.932510       4.758023      28.778732       1.462668
# min         0.000000      14.900000       3.300000       0.000000
# 25%         0.000000      24.200000      26.500000       1.400000
# 50%         4.300000      27.200000      59.300000       2.200000
# 75%       411.000000      31.100000      80.800000       3.200000
# max      1367.000000      41.400000      99.800000      16.100000
#
#               WSgust        WSstdev             WD        WDstdev  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean        3.229490       0.557740     161.741845      10.559568
# std         1.882565       0.268923      91.877217       5.915490
# min         0.000000       0.000000       0.000000       0.000000
# 25%         1.900000       0.400000      74.800000       6.900000
# 50%         2.900000       0.500000     199.100000      10.800000
# 75%         4.400000       0.700000     233.500000      14.100000
# max        23.100000       4.700000     360.000000      86.900000
#
#                   BP       Cleaning  Precipitation          TModA  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      975.915242       0.000535       0.001382      32.444403
# std         2.153977       0.023116       0.026350      10.998334
# min       968.000000       0.000000       0.000000      13.100000
# 25%       975.000000       0.000000       0.000000      23.900000
# 50%       976.000000       0.000000       0.000000      28.400000
# 75%       977.000000       0.000000       0.000000      40.600000
# max       983.000000       1.000000       2.300000      70.400000
#
#                TModB  Comments
# count  525600.000000       0.0
# mean       33.543330       NaN
# std        12.769277       NaN
# min        13.100000       NaN
# 25%        23.600000       NaN
# 50%        28.400000       NaN
# 75%        43.000000       NaN
# max        94.600000       NaN

# %%
# Checking for Missing Values-1
df.isna().any()
# Out:
# Timestamp        False
# GHI              False
# DNI              False
# DHI              False
# ModA             False
# ModB             False
# Tamb             False
# RH               False
# WS               False
# WSgust           False
# WSstdev          False
# WD               False
# WDstdev          False
# BP               False
# Cleaning         False
# Precipitation    False
# TModA            False
# TModB            False
# Comments          True
# dtype: bool

# %%
# Checking for Missing Values-2
df.isna().sum()
# Out:
# Timestamp             0
# GHI                   0
# DNI                   0
# DHI                   0
# ModA                  0
# ModB                  0
# Tamb                  0
# RH                    0
# WS                    0
# WSgust                0
# WSstdev               0
# WD                    0
# WDstdev               0
# BP                    0
# Cleaning              0
# Precipitation         0
# TModA                 0
# TModB                 0
# Comments         525600
# dtype: int64

# %%
# Checking for Outliers DNI

Q1_GHI = df['GHI'].quantile(0.25)
Q3_GHI = df['GHI'].quantile(0.75)

IQR_GHI = Q3_GHI -Q1_GHI

Lower_Bound_GHI = Q1_GHI - 1.5 * IQR_GHI
Upper_Bound_GHI = Q3_GHI + 1.5 * IQR_GHI

GHI_Outliers = df[(df['GHI']<Lower_Bound_GHI) | (df['GHI']> Upper_Bound_GHI) ]

GHI_Outliers
# Out:
#                Timestamp     GHI    DNI    DHI    ModA    ModB  Tamb    RH  \
# 4985    2021-10-28 11:06  1139.0  805.1  466.1  1172.0  1154.0  29.8  70.8
# 4995    2021-10-28 11:16  1112.0  800.3  429.1  1139.0  1120.0  30.5  68.7
# 195137  2022-03-09 12:18  1139.0  609.7  543.6  1139.6  1092.0  37.8   4.5
# 195138  2022-03-09 12:19  1152.0  619.7  549.9  1155.6  1108.0  37.7   4.4
# 195139  2022-03-09 12:20  1155.0  614.7  558.0  1158.6  1112.0  37.7   4.6
# ...                  ...     ...    ...    ...     ...     ...   ...   ...
# 510411  2022-10-14 10:52  1162.0  742.9  453.3  1196.2  1179.0  30.1  69.3
# 510412  2022-10-14 10:53  1285.0  862.8  460.8  1309.4  1290.0  30.1  67.8
# 510413  2022-10-14 10:54  1202.0  748.9  494.9  1242.3  1225.0  30.1  68.0
# 510414  2022-10-14 10:55  1267.0  790.9  514.5  1299.4  1280.0  30.1  68.6
# 510416  2022-10-14 10:57  1214.0  699.2  542.7  1244.3  1226.0  30.3  69.2
#
#          WS  WSgust  WSstdev     WD  WDstdev   BP  Cleaning  Precipitation  \
# 4985    2.2     2.6      0.4  298.6     13.4  977         0            0.0
# 4995    3.6     4.4      0.5  283.4      8.1  977         0            0.0
# 195137  1.0     1.9      0.7  354.4      8.3  973         0            0.0
# 195138  1.2     1.9      0.6  337.0     18.4  973         0            0.0
# 195139  1.2     2.1      0.7  312.4     16.3  973         0            0.0
# ...     ...     ...      ...    ...      ...  ...       ...            ...
# 510411  4.8     6.2      0.9  167.2     16.1  978         0            0.0
# 510412  5.1     6.4      0.9  182.7     13.4  978         0            0.0
# 510413  4.4     6.4      1.2  169.9     10.9  978         0            0.0
# 510414  4.0     5.2      0.9  160.1     15.0  978         0            0.0
# 510416  2.4     4.1      0.7  165.5     23.4  978         0            0.0
#
#         TModA  TModB  Comments
# 4985     44.7   50.2       NaN
# 4995     51.3   57.9       NaN
# 195137   55.2   59.5       NaN
# 195138   57.2   61.1       NaN
# 195139   59.4   63.1       NaN
# ...       ...    ...       ...
# 510411   53.2   62.6       NaN
# 510412   53.7   62.9       NaN
# 510413   54.2   63.4       NaN
# 510414   54.9   64.3       NaN
# 510416   56.1   65.6       NaN
#
# [1303 rows x 19 columns]

# %%
# Checking for Outliers DHI

Q1_DHI = df['DHI'].quantile(0.25)
Q3_DHI = df['DHI'].quantile(0.75)

IQR_DHI = Q3_DHI -Q1_DHI

Lower_Bound_DHI = Q1_DHI - 1.5 * IQR_DHI
Upper_Bound_DHI = Q3_DHI + 1.5 * IQR_DHI

DHI_Outliers = df[(df['DHI']<Lower_Bound_DHI) | (df['DHI']> Upper_Bound_DHI) ]

DHI_Outliers
# Out:
#                Timestamp    GHI    DNI    DHI    ModA   ModB  Tamb    RH   WS  \
# 559     2021-10-25 09:20  606.4  106.1  551.5   614.2  607.6  29.4  74.2  2.8
# 560     2021-10-25 09:21  678.5  187.9  564.2   688.7  681.0  29.4  75.8  2.4
# 561     2021-10-25 09:22  651.1  142.4  570.9   661.0  653.7  29.5  74.4  2.6
# 562     2021-10-25 09:23  659.3  142.5  575.4   664.2  656.8  29.5  74.9  2.6
# 563     2021-10-25 09:24  617.6   86.1  575.8   621.9  615.1  29.5  74.3  3.6
# ...                  ...    ...    ...    ...     ...    ...   ...   ...  ...
# 510555  2022-10-14 13:16  579.2   20.2  543.6   569.9  564.7  30.0  69.3  2.3
# 522047  2022-10-22 12:48  919.0  387.0  539.8   960.3  921.0  34.2  38.8  3.5
# 522054  2022-10-22 12:55  817.0  273.0  544.5   855.8  820.0  34.1  38.4  1.8
# 522055  2022-10-22 12:56  924.0  384.4  550.3   968.5  928.0  34.2  37.5  2.5
# 522056  2022-10-22 12:57  985.0  452.6  551.3  1030.0  987.0  34.2  35.6  2.5
#
#         WSgust  WSstdev     WD  WDstdev   BP  Cleaning  Precipitation  TModA  \
# 559        3.4      0.5  216.3     18.2  979         0            0.0   43.2
# 560        3.1      0.5  217.5     15.2  979         0            0.0   43.6
# 561        3.1      0.4  225.5     16.3  979         0            0.0   44.0
# 562        3.6      0.5  225.5     20.7  979         0            0.0   44.5
# 563        4.4      0.5  237.4      6.4  979         0            0.0   44.9
# ...        ...      ...    ...      ...  ...       ...            ...    ...
# 510555     4.1      0.8  188.3     13.9  976         0            0.0   45.0
# 522047     4.6      0.7  127.0     11.1  976         0            0.0   50.2
# 522054     2.6      0.5  111.7     23.0  976         0            0.0   49.7
# 522055     3.4      0.6   76.3     23.6  976         0            0.0   50.2
# 522056     3.1      0.4   75.2     11.1  976         0            0.0   50.4
#
#         TModB  Comments
# 559      48.9       NaN
# 560      49.5       NaN
# 561      50.1       NaN
# 562      50.8       NaN
# 563      51.3       NaN
# ...       ...       ...
# 510555   47.0       NaN
# 522047   51.9       NaN
# 522054   51.4       NaN
# 522055   51.8       NaN
# 522056   52.2       NaN
#
# [7905 rows x 19 columns]

# %%
# Checking for Outliers DHI

Q1_DHI = df['DHI'].quantile(0.25)
Q3_DHI = df['DHI'].quantile(0.75)

IQR_DHI = Q3_DHI -Q1_DHI

Lower_Bound_DHI = Q1_DHI - 1.5 * IQR_DHI
Upper_Bound_DHI = Q3_DHI + 1.5 * IQR_DHI

DHI_Outliers = df[(df['DHI']<Lower_Bound_DHI) | (df['DHI']> Upper_Bound_DHI) ]

DHI_Outliers
# Out:
#                Timestamp    GHI    DNI    DHI    ModA   ModB  Tamb    RH   WS  \
# 559     2021-10-25 09:20  606.4  106.1  551.5   614.2  607.6  29.4  74.2  2.8
# 560     2021-10-25 09:21  678.5  187.9  564.2   688.7  681.0  29.4  75.8  2.4
# 561     2021-10-25 09:22  651.1  142.4  570.9   661.0  653.7  29.5  74.4  2.6
# 562     2021-10-25 09:23  659.3  142.5  575.4   664.2  656.8  29.5  74.9  2.6
# 563     2021-10-25 09:24  617.6   86.1  575.8   621.9  615.1  29.5  74.3  3.6
# ...                  ...    ...    ...    ...     ...    ...   ...   ...  ...
# 510555  2022-10-14 13:16  579.2   20.2  543.6   569.9  564.7  30.0  69.3  2.3
# 522047  2022-10-22 12:48  919.0  387.0  539.8   960.3  921.0  34.2  38.8  3.5
# 522054  2022-10-22 12:55  817.0  273.0  544.5   855.8  820.0  34.1  38.4  1.8
# 522055  2022-10-22 12:56  924.0  384.4  550.3   968.5  928.0  34.2  37.5  2.5
# 522056  2022-10-22 12:57  985.0  452.6  551.3  1030.0  987.0  34.2  35.6  2.5
#
#         WSgust  WSstdev     WD  WDstdev   BP  Cleaning  Precipitation  TModA  \
# 559        3.4      0.5  216.3     18.2  979         0            0.0   43.2
# 560        3.1      0.5  217.5     15.2  979         0            0.0   43.6
# 561        3.1      0.4  225.5     16.3  979         0            0.0   44.0
# 562        3.6      0.5  225.5     20.7  979         0            0.0   44.5
# 563        4.4      0.5  237.4      6.4  979         0            0.0   44.9
# ...        ...      ...    ...      ...  ...       ...            ...    ...
# 510555     4.1      0.8  188.3     13.9  976         0            0.0   45.0
# 522047     4.6      0.7  127.0     11.1  976         0            0.0   50.2
# 522054     2.6      0.5  111.7     23.0  976         0            0.0   49.7
# 522055     3.4      0.6   76.3     23.6  976         0            0.0   50.2
# 522056     3.1      0.4   75.2     11.1  976         0            0.0   50.4
#
#         TModB  Comments
# 559      48.9       NaN
# 560      49.5       NaN
# 561      50.1       NaN
# 562      50.8       NaN
# 563      51.3       NaN
# ...       ...       ...
# 510555   47.0       NaN
# 522047   51.9       NaN
# 522054   51.4       NaN
# 522055   51.8       NaN
# 522056   52.2       NaN
#
# [7905 rows x 19 columns]

# %%
##df_zscore_scipy = df['GHI', 'DNI', 'DHI', 'ModA', 'ModB', 'WS', 'WSgust'].select_dtypes(include=np.number).apply(zscore)
df_zscore_scipy = df[['GHI', 'DNI', 'DHI', 'ModA', 'ModB', 'WS', 'WSgust']].apply(zscore)
df_zscore_scipy = df_zscore_scipy>3
df_zscore_scipy.sum()
# Out:
# GHI        305
# DNI       1062
# DHI       3415
# ModA       137
# ModB       206
# WS        3510
# WSgust    3915
# dtype: int64

# %%
plt.bar(df['Timestamp'],df['GHI'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 plt.bar(df['Timestamp'],df['GHI'])
#       2 plt.show()
#
# File c:\Users\henokt\OneDrive - Inchcape\Documents\GitHub\solar-challenge-week1\.venv\Lib\site-packages\matplotlib\pyplot.py:2989, in bar(x, height, width, bottom, align, data, **kwargs)
#    2978 @_copy_docstring_and_deprecators(Axes.bar)
#    2979 def bar(
#    2980     x: float | ArrayLike,
#    (...)   2987     **kwargs,
#    2988 ) -> BarContainer:
# -> 2989     return gca().bar(
#    2990         x,
#    2991         height,
#    2992         width=width,
#    2993         bottom=bottom,
#    2994         align=align,
#    2995         **({"data": data} if data is not None else {}),
#    2996         **kwargs,
#    2997     )
#
# File c:\Users\henokt\OneDrive - Inchcape\Documents\GitHub\solar-challenge-week1\.venv\Lib\site-packages\matplotlib\__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File c:\Users\henokt\OneDrive - Inchcape\Documents\GitHub\solar-challenge-week1\.venv\Lib\site-packages\matplotlib\axes\_axes.py:2572, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2570 if self.xaxis is not None:
#    2571     x0 = x
# -> 2572     x = np.asarray(self.convert_xunits(x))
#    2573     width = self._convert_dx(width, x0, x, self.convert_xunits)
#    2574     if xerr is not None:
#
# File c:\Users\henokt\OneDrive - Inchcape\Documents\GitHub\solar-challenge-week1\.venv\Lib\site-packages\matplotlib\artist.py:278, in Artist.convert_xunits(self, x)
#     276 if ax is None or ax.xaxis is None:
#     277     return x
# --> 278 return ax.xaxis.convert_units(x)
#
# File c:\Users\henokt\OneDrive - Inchcape\Documents\GitHub\solar-challenge-week1\.venv\Lib\site-packages\matplotlib\axis.py:1811, in Axis.convert_units(self, x)
#    1809     return x
#    1810 try:
# -> 1811     ret = self._converter.convert(x, self.units, self)
#    1812 except Exception as e:
#    1813     raise munits.ConversionError('Failed to convert value(s) to axis '
#    1814                                  f'units: {x!r}') from e
#
# File c:\Users\henokt\OneDrive - Inchcape\Documents\GitHub\solar-challenge-week1\.venv\Lib\site-packages\matplotlib\category.py:58, in StrCategoryConverter.convert(value, unit, axis)
#      56 # force an update so it also does type checking
#      57 unit.update(values)
# ---> 58 s = np.vectorize(unit._mapping.__getitem__, otypes=[float])(values)
#      59 return s if not cbook.is_scalar_or_string(value) else s[0]
#
# File c:\Users\henokt\OneDrive - Inchcape\Documents\GitHub\solar-challenge-week1\.venv\Lib\site-packages\numpy\lib\_function_base_impl.py:2544, in vectorize.__call__(self, *args, **kwargs)
#    2541     self._init_stage_2(*args, **kwargs)
#    2542     return self
# -> 2544 return self._call_as_normal(*args, **kwargs)
#
# File c:\Users\henokt\OneDrive - Inchcape\Documents\GitHub\solar-challenge-week1\.venv\Lib\site-packages\numpy\lib\_function_base_impl.py:2537, in vectorize._call_as_normal(self, *args, **kwargs)
#    2534     vargs = [args[_i] for _i in inds]
#    2535     vargs.extend([kwargs[_n] for _n in names])
# -> 2537 return self._vectorize_call(func=func, args=vargs)
#
# File c:\Users\henokt\OneDrive - Inchcape\Documents\GitHub\solar-challenge-week1\.venv\Lib\site-packages\numpy\lib\_function_base_impl.py:2628, in vectorize._vectorize_call(self, func, args)
#    2625 outputs = ufunc(*args, out=...)
#    2627 if ufunc.nout == 1:
# -> 2628     res = asanyarray(outputs, dtype=otypes[0])
#    2629 else:
#    2630     res = tuple(asanyarray(x, dtype=t)
#    2631                 for x, t in zip(outputs, otypes))
#
# KeyboardInterrupt:
